# %%
import pandas as pd

def calculate_prc(csv_path, sent):
    # Load CSV file
    df = pd.read_csv(csv_path)

    # Calculate total timesteps and total time waited
    total_timesteps = df['Timesteps'].sum()
    total_time_waited = df['Steps Waited'].sum()

    # Calculate percentage of time waited
    percentage_waited = (total_time_waited / total_timesteps) * 100

    print(f"Average Percentage of Time Waited{sent}: {percentage_waited:.2f}%")

print("A61 R5")
calculate_prc("A11/MULTI_R/RR/A11_R5_RR_LZP0_ST0_WN/A11_R5_RR_LZP0_ST0_WN.csv", "R5")
calculate_prc("A11/MULTI_R/RR/A11_R6_RR_LZP0_ST0_WN/A11_R6_RR_LZP0_ST0_WN.csv", "R6")
calculate_prc("A11/MULTI_R/RR/A11_R7_RR_LZP0_ST0_WN/A11_R7_RR_LZP0_ST0_WN.csv", "R7")
calculate_prc("A11/MULTI_R/RR/A11_R8_RR_LZP0_ST0_WN/A11_R8_RR_LZP0_ST0_WN.csv", "R8")
calculate_prc("A11/MULTI_R/RR/A11_R9_RR_LZP0_ST0_WN/A11_R9_RR_LZP0_ST0_WN.csv", "R9")
calculate_prc("A11/MULTI_R/RR/A11_R10_RR_LZP0_ST0_WN/A11_R10_RR_LZP0_ST0_WN.csv", "R10")
# Out:
# A61 R5
# Average Percentage of Time WaitedR5: 4.48%
# Average Percentage of Time WaitedR6: 5.65%
# Average Percentage of Time WaitedR7: 6.72%
# Average Percentage of Time WaitedR8: 7.90%
# Average Percentage of Time WaitedR9: 9.04%
# Average Percentage of Time WaitedR10: 10.11%

# %%
import pandas as pd

def calculate_prc(csv_path, sent):
    # Load CSV file
    df = pd.read_csv(csv_path)

    # Calculate total timesteps and total time waited
    total_timesteps = df['Timesteps'].sum()
    total_time_waited = df['Steps Waited'].sum()

    # Calculate percentage of time waited
    percentage_waited = (total_time_waited / total_timesteps) * 100

    print(f"Average Percentage of Time Waited{sent}: {percentage_waited:.2f}%")

print("A61 R5")
calculate_prc("A61_R5_RR_LZ-0_ST0_WN.csv", " at position ST0")

print("\nA61 R10")
calculate_prc("A61_R10_RR_LZ-0_ST0_WN.csv", " at position ST0")
# Out:
# A61 R5
# Average Percentage of Time Waited at position ST0: 0.13%
#
# A61 R10
# Average Percentage of Time Waited at position ST0: 0.30%
